# %% [markdown]
# # Setup

# %%
# Import libraries
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from crewai import Agent, Process, Crew, Task
from IPython.display import display, Markdown
import os
from crewai.knowledge.source.string_knowledge_source import StringKnowledgeSource

# %%
# Set the API keys as environment variables
load_dotenv() #KeyName = OpenAI_CrewAI_Key
# Out:
# True

# %%
# Define the LLM
llm = ChatOpenAI(model_name = "gpt-4o", temperature = 0.5)

# %% [markdown]
# # Get the data
# *   Interviewer
# *   company
# *   job position
# *   job description

# %%
# Store the data
interviewer = input("Enter the name of the interviewer: ")
company = input("Enter the name of the company: ")
job_position = input("Enter the job position: ")
job_description = input("Enter the job description: ")
# Out:
# Enter the name of the interviewer:  murali K
# Enter the name of the company:  intellect
# Enter the job position:  business analyst
# Enter the job description:  Key Responsibilities Requirements Gathering: Elicit and document business needs and functional requirements from stakeholders.  Data Analysis: Analyze large datasets to identify trends, patterns, and areas for improvement, often using tools like Excel, SQL, or Python.  Process Improvement: Evaluate existing processes and recommend changes to optimize performance, efficiency, and outcomes.  Stakeholder Communication: Facilitate communication between business leaders, IT, and other departments to ensure alignment.  Documentation & Reporting: Create clear reports, process maps, financial models, and data visualizations (charts, tables) for decision-making.  Solution Support: Assist with the implementation, testing, and monitoring of new systems, software, or workflows.  Essential Skills & Qualifications Education: Bachelor's degree in Business, Finance, Computer Science, or related fields.  Analytical Skills: Strong problem-solving, critical thinking, and data interpretation.  Technical Skills: Proficiency with data tools (Excel, SQL, Tableau) and understanding of IT systems.  Communication: Excellent written, verbal, and presentation skills to bridge technical and business gaps.  Business Acumen: Understanding of business strategies, goals, and commercial awareness.  Typical Tools & Technologies Microsoft Excel, SQL Data Visualization (Tableau, Power BI) Project Management Software Modeling & Diagramming Tools (Visio, Lucidchart) Programming (Python/R for more advanced roles)

# %% [markdown]
# ## Interviewer AI Agent

# %%
# Create the interver AI agent
interviewer_agent = Agent(
    role = f" You are {interviewer}, employed at {company}, and hiring for job position {job_position}",
    goal = f" you help the user user prepare for the job interview for job {job_position} with the following description: {job_description}",
    backstory = """
    Experience
    BEAT81
    Analytics Engineer

    BEAT81 · Full-timeBEAT81 · Full-time
    Apr 2024 - Present · 11 mos
    Berlin, Germany
    diconium
    Full-time · 4 yrs 2 mosFull-time · 4 yrs 2 mos

    Senior Cloud Architect
    Apr 2022 - Mar 2024 · 2 yrs
    Microsoft Azure, DBT and +4 skills

    Data Engineer
    Jan 2021 - Mar 2022 · 1 yr 3 mosJan 2021 to Mar 2022 · 1 yr 3 mos
    DBT, AWS and +4 skills

    Data Scientist
    Feb 2020 - Dec 2020 · 11 mos
    SQL and Python
    4flow logo

    Data Scientist
    4flow · Full-time4flow · Full-time
    Jun 2019 - Dec 2019 · 7 mosJun 2019 to Dec 2019 · 7 mos
    SQL and Python
    DCMN
    Full-time · 3 yrs 3 mos

    Data Scientist
    Apr 2017 - Apr 2019 · 2 yrs 1 moApr 2017 to Apr 2019 · 2 yrs 1 mo
    SQL and Python
    Data Analyst / Business Intelligence Manager

    Feb 2016 - Mar 2017 · 1 yr 2 mosFeb 2016 to Mar 2017 · 1 yr 2 mos
    SQL and Python
    iversity logo

    Data Analyst
    iversity · Full-timeiversity · Full-time
    Dec 2014 - Dec 2015 · 1 yr 1 moDec 2014 to Dec 2015 · 1 yr 1 mo
    SQL and R

    Education
    Technische Universität Berlin
    Master of Science - MS, Computational Neuroscience
    Sep 2009 - Aug 2013

    Universität Osnabrück
    Bachelor of Science - BS, Cognitive ScienceBachelor of Science - BS, Cognitive Science
    """,
    llm = llm
)

# %%
# Define the interview prep task
interview_prep_task = Task(
    description = f"""
    Interview the user for the job {job_position} with the following description: {job_description}
    """,
    expected_output = f"""
    ask only one question to the user that is relevant for the job {job_position} that has not been asked before
    """,
    agent = interviewer_agent,
    human_input = True
)

# %% [markdown]
# ## AI Coach

# %%
# Build the AI interview coach agent
coach_agent = Agent(
    role = "Interview Coach",
    goal = f"I help the user prepare for the job interview for job {job_position} by grading the relevance of the answer",
    backstory = "You are an expert in job interviews",
    llm = llm)

# %%
# Define the Coaching Task
coaching_task = Task(
    description = """ Give feedback to the user on its answer """,
    expected_output = f""" Give feedback to the user on its answer with a bullet points on what was good, bad, and how to take it to the next level""",
    agent = coach_agent,
    context = [interview_prep_task]
)

# %% [markdown]
# ## AI Crew

# %%
# Create an empty list for questions
interview_questions = []
# # Store each question
# interview_questions.append(result.tasks_output[0].raw)
# interview_content = ' '.join(interview_questions)
# string_source = StringKnowledgeSource(content = interview_content)

# %%
crew = Crew(
    agents = [interviewer_agent, coach_agent],
    tasks = [interview_prep_task, coaching_task],
    verbose = True,
    process = Process.sequential,
    memory = True,
   # knowledge_sources = [string_source]
)
result = crew.kickoff()

# # Store each question
# interview_questions.append(result.tasks_output[0].raw)
# interview_content = ' '.join(interview_questions)
# string_source = StringKnowledgeSource(content = interview_content)
# Out:
# # Agent:  You are murali K, employed at intellect, and hiring for job position business analyst
# ## Task:
#     Interview the user for the job business analyst with the following description: Key Responsibilities Requirements Gathering: Elicit and document business needs and functional requirements from stakeholders.  Data Analysis: Analyze large datasets to identify trends, patterns, and areas for improvement, often using tools like Excel, SQL, or Python.  Process Improvement: Evaluate existing processes and recommend changes to optimize performance, efficiency, and outcomes.  Stakeholder Communication: Facilitate communication between business leaders, IT, and other departments to ensure alignment.  Documentation & Reporting: Create clear reports, process maps, financial models, and data visualizations (charts, tables) for decision-making.  Solution Support: Assist with the implementation, testing, and monitoring of new systems, software, or workflows.  Essential Skills & Qualifications Education: Bachelor's degree in Business, Finance, Computer Science, or related fields.  Analytical Skills: Strong problem-solving, critical thinking, and data interpretation.  Technical Skills: Proficiency with data tools (Excel, SQL, Tableau) and understanding of IT systems.  Communication: Excellent written, verbal, and presentation skills to bridge technical and business gaps.  Business Acumen: Understanding of business strategies, goals, and commercial awareness.  Typical Tools & Technologies Microsoft Excel, SQL Data Visualization (Tableau, Power BI) Project Management Software Modeling & Diagramming Tools (Visio, Lucidchart) Programming (Python/R for more advanced roles)
#
#
#
# # Agent:  You are murali K, employed at intellect, and hiring for job position business analyst
# ## Final Answer:
# Can you provide an example of a time when you identified a significant trend or pattern in a dataset that led to a process improvement or strategic decision in your previous roles? Please describe the tools and methodologies you used, and how you communicated your findings to stakeholders.
#
#
#  ## Final Result: Can you provide an example of a time when you identified a significant trend or pattern in a dataset that led to a process improvement or strategic decision in your previous roles? Please describe the tools and methodologies you used, and how you communicated your findings to stakeholders.
#
#
# =====
# ## Please provide feedback on the Final Result and the Agent's actions:
#  pretty great
# # Agent:  You are murali K, employed at intellect, and hiring for job position business analyst
# ## Final Answer:
# Thank you for the feedback! If there's anything more specific you'd like to discuss or any other questions you have regarding the role, feel free to ask. I'm here to help!
#
#
# # Agent: Interview Coach
# ## Task:  Give feedback to the user on its answer
#
#
# # Agent: Interview Coach
# ## Final Answer:
# - **What was good:**
#   - The response is polite and open-ended, which encourages further communication. This is a positive trait for a business analyst, as it demonstrates a willingness to engage and assist.
#   - The use of "Thank you for the feedback!" shows appreciation and acknowledges the feedback received, which is important in maintaining good professional relationships.
#   - Offering help and inviting further questions is proactive and shows a readiness to collaborate, which is essential in a business analyst role.
#
# - **What could be improved:**
#   - The response could be more specific by mentioning the particular feedback that was appreciated. This would show attentiveness and a deeper understanding of the feedback given.
#   - It could include a brief reflection on how the feedback will be utilized to improve or maintain performance in the role.
#
# - **How to take it to the next level:**
#   - Consider adding a specific example or detail about how you plan to apply the feedback in your future interactions or work as a business analyst.
#   - You might say something like, "I appreciate your feedback on my analytical approach and will continue to incorporate data-driven insights in my analyses."
#   - This demonstrates a commitment to growth and shows that you are actively thinking about how to apply feedback to your professional development.

# %%
# Check output
display(Markdown(result.tasks_output[0].raw))
# Out:
# Thank you for the feedback! If there's anything more specific you'd like to discuss or any other questions you have regarding the role, feel free to ask. I'm here to help!
